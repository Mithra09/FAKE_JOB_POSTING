# %% [markdown]
# FAKE JOB PREDICITION

# %%
# !wget "https://assets.telegraphindia.com/telegraph/2022/Sep/1664219702_job-scams.jpg" -O demo.jpg
# Out:
# --2022-10-03 06:26:02--  https://assets.telegraphindia.com/telegraph/2022/Sep/1664219702_job-scams.jpg
# Resolving assets.telegraphindia.com (assets.telegraphindia.com)... 104.95.211.189, 2600:1408:5400:4a7::5cb, 2600:1408:5400:495::5cb
# Connecting to assets.telegraphindia.com (assets.telegraphindia.com)|104.95.211.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38616 (38K) [image/jpeg]
# Saving to: ‘demo.jpg’
#
# demo.jpg            100%[===================>]  37.71K  --.-KB/s    in 0.01s
#
# 2022-10-03 06:26:03 (2.90 MB/s) - ‘demo.jpg’ saved [38616/38616]

# %%
 import cv2
 from google.colab.patches import cv2_imshow

img=cv2.imread('/content/demo.jpg',255)
cv2_imshow(img)
cv2.imwrite('demo1.jpg',img) # saving the image
# Out:
# <PIL.Image.Image image mode=RGB size=348x261 at 0x7FC08028BE50>
# True

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Anshupriya2694/Fake-Job-Posting-Prediction/13e0e74b288b55605e2aa55392a82e86d28de053/data/fake_job_postings_cleaned.csv')
df
# Out:
#        Unnamed: 0  telecommuting  fraudulent  ratio  \
# 0               0              0           0   0.03
# 1               1              0           0   0.03
# 2               2              0           0   0.03
# 3               3              0           0   0.03
# 4               4              0           0   0.03
# ...           ...            ...         ...    ...
# 10588       10588              1           1   0.00
# 10589       10589              0           0   0.00
# 10590       10590              0           0   0.00
# 10591       10591              0           0   0.00
# 10592       10592              0           0   0.00
#
#                                                     text  character_count
# 0      Marketing Intern US, NY, New York We're Food52...             2705
# 1      Visual Designer US, NY, New York Kettle is an ...             1991
# 2      Payroll Tax Specialist US, NY, New York Namely...             1564
# 3      Marketing Manager US, NY, New York Super Socce...             2871
# 4      English Teacher Abroad US, NY, New York We hel...              669
# ...                                                  ...              ...
# 10588  Military Benefits Counselor US, , chicago Anth...             1173
# 10589  Sr.Business Intelligence Technical Architect U...             1270
# 10590  Licensed Practical Nurse (LPN)- Private Duty U...             2124
# 10591  SAS Grid Developer US, NJ, Berkeley Heights   ...             1540
# 10592  Sr. Scm Web Development Technical Lead US, CA,...             2013
#
# [10593 rows x 6 columns]

# %%
df.shape #number of rows and columns in dataframe
# Out:
# (10593, 6)

# %%
df.size #size of the dataframe
# Out:
# 63558

# %%
df.info() #information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10593 entries, 0 to 10592
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10593 non-null  int64
#  1   telecommuting    10593 non-null  int64
#  2   fraudulent       10593 non-null  int64
#  3   ratio            10593 non-null  float64
#  4   text             10593 non-null  object
#  5   character_count  10593 non-null  int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 496.7+ KB

# %%
df.isnull().sum() #checking the null values in each column
# Out:
# Unnamed: 0         0
# telecommuting      0
# fraudulent         0
# ratio              0
# text               0
# character_count    0
# dtype: int64

# %%
X = df[['telecommuting', 'ratio',  'character_count']] #x is input in 2 dimensional array
y = df['fraudulent'] #y is input in 1 dimensional array

# %%
X.ndim #number of dimensions
# Out:
# 2

# %%
y.ndim #number of dimensions
# Out:
# 1

# %%
np.unique(df['fraudulent'],return_counts=True) #returns unique of array  0,REAL 1,FAKE
# Out:
# (array([0, 1]), array([9868,  725]))

# %%
df['ratio'].value_counts().plot(kind='pie')

# %%
df['fraudulent'].value_counts().plot(kind='pie')#kind=bar,barh

# %%
sns.barplot(x='ratio',y='fraudulent',data=df,) #plotting the ratio of number of fake(1) and real(0) jobs

# %%
corr = df.corr()
sns.heatmap(corr)
plt.show()

# %%
sns.countplot(x='fraudulent', data=df); #counting the fake and real jobs

# %%
df['character_count'] = df.text.apply(len)

df[df.fraudulent==0].character_count.plot(bins=35, kind='hist', color='blue', 
                                       label='Real', alpha=0.8)
df[df.fraudulent==1].character_count.plot(kind='hist', color='red', 
                                       label='Fake', alpha=0.8)
plt.legend()
plt.title('Frequency of Words')
plt.xlabel("Character Count");

# %% [markdown]
# MULTILINEAR REGRESSION

# %%
#split the data to predict the fraudulent
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
y_test.shape
# Out:
# (7944, 3)
# (2649, 3)
# (7944,)
# (2649,)

# %%
# Import Linear Regression algorithm 
from sklearn.linear_model import LinearRegression

# %%
# calling the algorithm 
model = LinearRegression()

# %%
#training the machine 
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#pred the output
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0.08852636, 0.07283026, 0.0491062 , ..., 0.0828509 , 0.06881005,
#        0.02887403])

# %%
y_test.values
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df1 = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df1
# Out:
#        Actual  Predicted
# 4647        0   0.088526
# 5121        0   0.072830
# 5025        0   0.049106
# 10189       0  -0.002207
# 6967        0   0.092519
# ...       ...        ...
# 2551        0   0.070550
# 7878        0   0.206134
# 6639        0   0.082851
# 9357        0   0.068810
# 10332       0   0.028874
#
# [2649 rows x 2 columns]

# %%
sns.distplot(df['fraudulent']) #exploratory data analysis (EDA)-to analyze and investigate data sets and summarize the characteristics
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Data visualization 
sns.regplot(x='Actual',y='Predicted',data=df1,color='purple',marker='*')

# %%
df1.plot(figsize=(10,10),kind='bar')

# %% [markdown]
# CLASSIFICATION

# %% [markdown]
# K CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=102)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=102)

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10588    1
# 10589    0
# 10590    0
# 10591    0
# 10592    0
# Name: fraudulent, Length: 10593, dtype: int64

# %%
from sklearn.metrics import accuracy_score #accuracy score
accuracy_score(y,y_pred)
# Out:
# 0.9315585764183895

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y,y_pred)
# Out:
# array([[9868,    0],
#        [ 725,    0]])

# %%
accuracy=(9868+0)/(9868+0+725+0)
accuracy
# Out:
# 0.9315585764183895

# %%
precision = (9868)/(9868+0)
precision
# Out:
# 1.0

# %%
recall = (9686)/(9686+725)
recall
# Out:
# 0.9303621169916435

# %%
f1_score = 2*((precision*recall)/(precision+recall))
f1_score
# Out:
# 0.9639249639249639

# %%
import seaborn as sns 

sns.heatmap(confusion_matrix(y,y_pred),annot=True,cmap='Blues')
